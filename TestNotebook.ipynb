# %% [markdown]
# # Technical Assessment - Data Scientist
# ### Author: Nicolas Santos
# ### August 2022
# ---

# %% [markdown]
# ### Table of Contents
#
# - [1. Notebook Set-up](#setup)
# - [2. Data Cleaning](#clean)
#     - [2.1 General Data](#general)
#     - [2.2 Underwriting Data](#under)
#     - [2.3 Data Dictionary](#dict)
#     - [2.4 Further Cleaning: Outliers](#further)
# - [3. Firm Selection](#selection)
# ---

# %% [markdown]
# ### 1 Notebook set-up <a class="anchor" id="setup"></a>

# %%
#Housekeeping 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %% [markdown]
# Formating the aesthetics of the notebook.

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# %%html
# <style>
# table {float:left}
# </style>
# Out:
# <style>
# table {float:left}
# </style>

# %% [markdown]
# ### 2 Data Cleaning<a class="anchor" id="clean"></a>

# %% [markdown]
# #### 2.1 General Data<a class="anchor" id="general"></a>

# %% [markdown]
# On a first stage I clean the structure of the data in both workbooks. Once I have an ideal data structure to work with I can proceed to study the distributions to identify possible outliers for further cleaning.

# %%
#Load raw excel file
data_raw = pd.read_excel(r'C:\Users\nsant\Documents\BoE\data\Data for technical assessment.xlsx', 
                             sheet_name="Dataset 1 - General", header = 1)

data_raw.rename(columns = {'Unnamed: 0':'ID'}, inplace = True)
data_raw.rename(columns = {'2016YE':'2016YE.0', 
                           '2017YE':'2017YE.0', 
                           '2017YE':'2017YE.0', 
                           '2018YE':'2018YE.0', 
                           '2019YE':'2019YE.0', 
                           '2020YE':'2020YE.0'}, inplace = True)
# Reshape data
data_raw = pd.wide_to_long(data_raw, stubnames = ["2016YE", "2017YE", "2018YE", "2019YE", "2020YE"], i="ID", j="Series", sep='.')

data_raw.rename(columns = {'2016YE':'v2016', 
                           '2017YE':'v2017', 
                           '2017YE':'v2017', 
                           '2018YE':'v2018', 
                           '2019YE':'v2019', 
                           '2020YE':'v2020'}, inplace = True)

#Dictionary with series name
series_dic = {0:'NWP', 1:'SCR', 2:'EoF_SCR', 3:'SCR_CR', 4:'GWP', 5:'TOT_ASSETS', 6:'TOTAL_LIAB', 7:'EXCESS'}

#Add series names to DF
data_raw = data_raw.reset_index()
for k, v in series_dic.items():
    data_raw = data_raw.replace({'Series': k}, v)

#Remove string from ID
data_raw['ID'] = data_raw['ID'].str.replace('Firm ','')

#Final reshaping
data_raw = pd.wide_to_long(data_raw, stubnames='v', i=['ID','Series'], j ='Year')
data_raw = data_raw.reset_index()
general_data = pd.pivot(data_raw, index=['ID','Year'], columns = 'Series', values='v')
general_data = general_data.reset_index()
general_data = general_data.astype({'ID':'int'})
general_data = general_data.sort_values(by=['ID', 'Year'])
display(general_data)
# Out:
# Series   ID  Year       EXCESS      EoF_SCR          GWP           NWP  \
# 0         1  2016  2031.035937  2230.076702  1409.484796 -13779.815629
# 1         1  2017     4.817920     4.817920     0.000000      0.000000
# 2         1  2018     0.000000     0.000000     0.000000      0.000000
# 3         1  2019     0.000000     0.000000     0.000000      0.000000
# 4         1  2020     0.000000     0.000000     0.000000      0.000000
# ...     ...   ...          ...          ...          ...           ...
# 1255    325  2016   285.129083   285.129083   477.737541    240.999886
# 1256    325  2017   339.565646   339.565646   439.224098    252.698937
# 1257    325  2018   334.288033   334.288033   479.519316    332.521848
# 1258    325  2019   326.848756   326.848756   410.711127    294.886332
# 1259    325  2020     0.000000     0.000000     0.000000      0.000000
#
# Series           SCR        SCR_CR    TOTAL_LIAB    TOT_ASSETS
# 0       1.085360e+03  1.979865e+00  69696.557128  71727.593066
# 1       9.635840e-09  4.817920e+08      0.000000      4.817920
# 2       0.000000e+00  0.000000e+00      0.000000      0.000000
# 3       0.000000e+00  0.000000e+00      0.000000      0.000000
# 4       0.000000e+00  0.000000e+00      0.000000      0.000000
# ...              ...           ...           ...           ...
# 1255    2.091815e+02  1.313433e+00   1036.142704   1321.271787
# 1256    2.238009e+02  1.462014e+00   1044.558032   1384.123678
# 1257    2.568627e+02  1.254034e+00   1172.729179   1507.017211
# 1258    2.402959e+02  1.310660e+00   1171.754721   1498.603477
# 1259    0.000000e+00  0.000000e+00      0.000000      0.000000
#
# [1625 rows x 10 columns]

# %% [markdown]
# The data structure above is ideal for data wranggling. I will repeat the process for the Underwriting data before merging both datasets.

# %% [markdown]
# #### 2.2 Underwriting Data<a class="anchor" id="under"></a>

# %%
#Load raw excel file
data_raw = pd.read_excel(r'C:\Users\nsant\Documents\BoE\data\Data for technical assessment.xlsx', 
                             sheet_name="Dataset 2 - Underwriting", header = 1)

data_raw.rename(columns = {'Unnamed: 0':'ID'}, inplace = True)
data_raw.rename(columns = {'2016YE':'2016YE.0', 
                           '2017YE':'2017YE.0', 
                           '2017YE':'2017YE.0', 
                           '2018YE':'2018YE.0', 
                           '2019YE':'2019YE.0', 
                           '2020YE':'2020YE.0'}, inplace = True)
# Reshape data
data_raw = pd.wide_to_long(data_raw, stubnames = ["2016YE", "2017YE", "2018YE", "2019YE", "2020YE"], i="ID", j="Series", sep='.')

data_raw.rename(columns = {'2016YE':'v2016', 
                           '2017YE':'v2017', 
                           '2017YE':'v2017', 
                           '2018YE':'v2018', 
                           '2019YE':'v2019', 
                           '2020YE':'v2020'}, inplace = True)

#Dictionary with series name
series_dic = {0:'GCI', 1:'GBEL', 2:'NBEL', 3:'PNCR', 4:'NER', 5:'NCR', 6:'PGCR', 7:'GER', 8:'GCR'}

#Add series names to DF
data_raw = data_raw.reset_index()
for k, v in series_dic.items():
    data_raw = data_raw.replace({'Series': k}, v)

#Remove string from ID
data_raw['ID'] = data_raw['ID'].str.replace('Firm ','')

#Final reshaping
data_raw = pd.wide_to_long(data_raw, stubnames='v', i=['ID','Series'], j ='Year')
data_raw = data_raw.reset_index()

under_data = pd.pivot(data_raw, index=['ID','Year'], columns = 'Series', values='v')
under_data = under_data.reset_index()
under_data = under_data.astype({'ID':'int'})
under_data = under_data.sort_values(by=['ID', 'Year'])
display(under_data)
# Out:
# Series   ID  Year       GBEL       GCI        GCR        GER      NBEL  \
# 0         1  2016   0.000000  0.000000   0.000000   0.000000  0.000000
# 1         1  2017   7.674468  0.046674  68.215239  56.813725  7.674468
# 2         1  2018   0.000000  0.000000   0.000000   0.000000  0.000000
# 3         1  2019   0.000000  0.000000   0.000000   0.000000  0.000000
# 4         1  2020   0.000000  0.000000   0.000000   0.000000  0.000000
# ...     ...   ...        ...       ...        ...        ...       ...
# 1255    325  2016  15.279072  1.198052   0.164648   0.044248  4.571224
# 1256    325  2017  14.482158  1.376840   0.183376   0.040154  3.792835
# 1257    325  2018  13.716927  3.804573   0.427933   0.037627  4.347587
# 1258    325  2019  13.027975  2.301670   0.274733   0.043566  3.384191
# 1259    325  2020  12.364885  1.338178   0.180449   0.045283  2.998365
#
# Series        NCR        NER       PGCR       PNCR
# 0        0.000000   0.000000   0.000000   0.000000
# 1       68.215239  56.813725  11.401514  11.401514
# 2        0.000000   0.000000   0.000000   0.000000
# 3        0.000000   0.000000   0.000000   0.000000
# 4        0.000000   0.000000   0.000000   0.000000
# ...           ...        ...        ...        ...
# 1255     0.000000   0.000000   0.120400   0.000000
# 1256     0.000000   0.000000   0.143222   0.000000
# 1257     0.000000   0.000000   0.390306   0.000000
# 1258     0.000000   0.000000   0.231167   0.000000
# 1259     0.000000   0.000000   0.135166   0.000000
#
# [1625 rows x 11 columns]

# %% [markdown]
# Now we have two data frames with a tidy structure that we can merge together.

# %%
#Merge datasets
main_data = general_data.merge(under_data, on = ['ID', 'Year'] )
display(main_data)
# Out:
# Series   ID  Year       EXCESS      EoF_SCR          GWP           NWP  \
# 0         1  2016  2031.035937  2230.076702  1409.484796 -13779.815629
# 1         1  2017     4.817920     4.817920     0.000000      0.000000
# 2         1  2018     0.000000     0.000000     0.000000      0.000000
# 3         1  2019     0.000000     0.000000     0.000000      0.000000
# 4         1  2020     0.000000     0.000000     0.000000      0.000000
# ...     ...   ...          ...          ...          ...           ...
# 1620    325  2016   285.129083   285.129083   477.737541    240.999886
# 1621    325  2017   339.565646   339.565646   439.224098    252.698937
# 1622    325  2018   334.288033   334.288033   479.519316    332.521848
# 1623    325  2019   326.848756   326.848756   410.711127    294.886332
# 1624    325  2020     0.000000     0.000000     0.000000      0.000000
#
# Series           SCR        SCR_CR    TOTAL_LIAB    TOT_ASSETS       GBEL  \
# 0       1.085360e+03  1.979865e+00  69696.557128  71727.593066   0.000000
# 1       9.635840e-09  4.817920e+08      0.000000      4.817920   7.674468
# 2       0.000000e+00  0.000000e+00      0.000000      0.000000   0.000000
# 3       0.000000e+00  0.000000e+00      0.000000      0.000000   0.000000
# 4       0.000000e+00  0.000000e+00      0.000000      0.000000   0.000000
# ...              ...           ...           ...           ...        ...
# 1620    2.091815e+02  1.313433e+00   1036.142704   1321.271787  15.279072
# 1621    2.238009e+02  1.462014e+00   1044.558032   1384.123678  14.482158
# 1622    2.568627e+02  1.254034e+00   1172.729179   1507.017211  13.716927
# 1623    2.402959e+02  1.310660e+00   1171.754721   1498.603477  13.027975
# 1624    0.000000e+00  0.000000e+00      0.000000      0.000000  12.364885
#
# Series       GCI        GCR        GER      NBEL        NCR        NER  \
# 0       0.000000   0.000000   0.000000  0.000000   0.000000   0.000000
# 1       0.046674  68.215239  56.813725  7.674468  68.215239  56.813725
# 2       0.000000   0.000000   0.000000  0.000000   0.000000   0.000000
# 3       0.000000   0.000000   0.000000  0.000000   0.000000   0.000000
# 4       0.000000   0.000000   0.000000  0.000000   0.000000   0.000000
# ...          ...        ...        ...       ...        ...        ...
# 1620    1.198052   0.164648   0.044248  4.571224   0.000000   0.000000
# 1621    1.376840   0.183376   0.040154  3.792835   0.000000   0.000000
# 1622    3.804573   0.427933   0.037627  4.347587   0.000000   0.000000
# 1623    2.301670   0.274733   0.043566  3.384191   0.000000   0.000000
# 1624    1.338178   0.180449   0.045283  2.998365   0.000000   0.000000
#
# Series       PGCR       PNCR
# 0        0.000000   0.000000
# 1       11.401514  11.401514
# 2        0.000000   0.000000
# 3        0.000000   0.000000
# 4        0.000000   0.000000
# ...           ...        ...
# 1620     0.120400   0.000000
# 1621     0.143222   0.000000
# 1622     0.390306   0.000000
# 1623     0.231167   0.000000
# 1624     0.135166   0.000000
#
# [1625 rows x 19 columns]

# %% [markdown]
# With so many acronyms in the variable names it is good idea to create a dictionary for reference.

# %% [markdown]
# #### 2.3 Data Dictionary <a class="anchor" id="dict"></a>
#
#
# - EXCESS: Excess of assets over liabilities
# - EoF_SCR: EoF for SCR
# - GWP: Gross written premium
# - NWP: Net written premium
# - SCR: Solvency capital requirement
# - SCR_CR: SCR coverage ratio
# - TOTAL_LIAB: Total liabilities
# - TOT_ASSETS: Total assets
# - GBEL: Gross best estimate liability
# - GCI: Gross claims incurred
# - GCR: Gross combined ratio
# - GER: Gross expense ratio
# - NBEL: Net best estimate liability
# - NCR: Net combined ratio
# - NER: Net expense ratio
# - PGCR: Pure gross claims ratio
# - PNCR: Pure net claims ratio

# %% [markdown]
# #### 2.4 Further Cleaning: Outliers <a class="anchor" id="further"></a>

# %%
#Descriptive statistics
pd.set_option('display.float_format', lambda x:'%.2f'%x)
ds = main_data.describe().round(2).T
display(ds)
pd.reset_option('display.float_format')
# Out:
#              count       mean         std       min     25%     50%     75%  \
# Series
# ID         1625.00     163.00       93.85      1.00   82.00  163.00  244.00
# Year       1625.00    2018.00        1.41   2016.00 2017.00 2018.00 2019.00
# EXCESS     1625.00     524.53     2020.14   -110.79    5.26   34.13  181.99
# EoF_SCR    1625.00     526.67     2072.96   -110.79    5.22   33.29  182.02
# GWP        1625.00     920.32     3863.43    -95.42    0.00   13.71  229.07
# NWP        1625.00     744.39     3473.41 -13779.82    0.00    6.70  124.46
# SCR        1625.00     338.49     1396.45      0.00    1.44   14.18  102.75
# SCR_CR     1625.00 1191339.34 29260879.89     -1.97    1.24    1.66    2.75
# TOTAL_LIAB 1625.00    6762.98    29092.31  -1521.33    1.41   55.81  746.50
# TOT_ASSETS 1625.00    7287.51    30437.71   -217.43   12.86  117.07 1008.41
# GBEL       1625.00     294.59      851.41   -135.49    0.00    9.06  183.48
# GCI        1625.00     137.53      402.58    -98.00    0.00    2.00   90.59
# GCR        1625.00    1992.91    80706.67 -34649.42    0.00    0.64    0.97
# GER        1625.00     825.77    33293.35  -8773.16    0.00    0.18    0.34
# NBEL       1625.00     190.83      591.24   -104.84    0.00    3.03  107.04
# NCR        1625.00    1472.32    60292.93 -46116.70    0.00    0.64    0.99
# NER        1625.00     890.07    36000.26  -8766.06    0.00    0.18    0.41
# PGCR       1625.00    1167.14    47413.85 -25876.27    0.00    0.26    0.64
# PNCR       1625.00     582.25    24300.15 -37350.64    0.00    0.12    0.62
#
#                     max
# Series
# ID               325.00
# Year            2020.00
# EXCESS         24786.14
# EoF_SCR        28772.49
# GWP            48117.99
# NWP            48117.99
# SCR            19600.26
# SCR_CR     963584000.00
# TOTAL_LIAB    331981.94
# TOT_ASSETS    332875.90
# GBEL           10094.58
# GCI             4487.91
# GCR          3253168.86
# GER          1342061.31
# NBEL            7539.12
# NCR          2430022.84
# NER          1451186.53
# PGCR         1911107.55
# PNCR          978836.31

# %% [markdown]
# There seem to be several noticeable outliers in the variables of our data set. I will get rid of outliers using the Z-scores of the observations across all variables. I an observation has an outlier in at least one column it will be removed.

# %%
# Removing data based on Z-scores
data_clean = main_data[(np.abs(stats.zscore(main_data)) < 3).all(axis=1)]

# Re-calculating descriptive statistics
pd.set_option('display.float_format', lambda x:'%.2f'%x)
ds = data_clean.describe().round(2).T
display(ds)
pd.reset_option('display.float_format')
# Out:
#              count    mean       std       min     25%     50%     75%  \
# Series
# ID         1521.00  165.28     92.30      1.00   86.00  166.00  245.00
# Year       1521.00 2018.00      1.42   2016.00 2017.00 2018.00 2019.00
# EXCESS     1521.00  241.68    654.92   -110.79    5.13   30.67  154.54
# EoF_SCR    1521.00  246.84    670.76   -110.79    4.99   30.22  153.18
# GWP        1521.00  384.19   1227.53    -95.42    0.00   10.74  173.94
# NWP        1521.00  303.68   1134.35  -2305.85    0.00    5.29   83.60
# SCR        1521.00  156.29    445.45      0.00    1.18   12.85   87.31
# SCR_CR     1521.00 5287.79 145800.65     -1.97    1.22    1.67    2.79
# TOTAL_LIAB 1521.00 2517.10   9102.64  -1521.33    1.09   46.80  529.92
# TOT_ASSETS 1521.00 2758.78   9593.11   -217.43   11.64  107.03  827.74
# GBEL       1521.00  161.63    340.49   -135.49    0.00    5.64  143.92
# GCI        1521.00   77.15    168.93    -98.00    0.00    1.17   76.34
# GCR        1521.00   -9.75    951.92 -34649.42    0.00    0.53    0.96
# GER        1521.00   -0.17    253.32  -8773.16    0.00    0.13    0.34
# NBEL       1521.00  105.71    243.03   -104.84    0.00    1.37   86.07
# NCR        1521.00  -24.75   1185.27 -46116.70    0.00    0.34    0.98
# NER        1521.00   -3.23    227.95  -8766.06    0.00    0.08    0.41
# PGCR       1521.00   -9.58    703.71 -25876.27    0.00    0.16    0.63
# PNCR       1521.00  -21.52    958.84 -37350.64    0.00    0.00    0.61
#
#                   max
# Series
# ID             325.00
# Year          2020.00
# EXCESS        6429.02
# EoF_SCR       6465.46
# GWP          11020.37
# NWP          11020.37
# SCR           4105.90
# SCR_CR     4181572.98
# TOTAL_LIAB   79870.40
# TOT_ASSETS   83298.94
# GBEL          2838.53
# GCI           1248.20
# GCR          12408.54
# GER           4087.26
# NBEL          1760.82
# NCR           1738.30
# NER            728.20
# PGCR          8321.27
# PNCR          1037.51

# %% [markdown]
# After this process a 6.4% of the sample is dropped.

# %% [markdown]
# ### 3 Firm Selection <a class="anchor" id="Selection"></a>

# %%
data2020=data_clean[data_clean['Year']==2020]
data2020=data2020[['ID', 'GWP', 'NWP', 'SCR_CR', 'GCI', 'NCR', 'TOT_ASSETS']]
data2020
# Out:
# Series   ID          GWP          NWP    SCR_CR         GCI       NCR  \
# 4         1     0.000000     0.000000  0.000000    0.000000  0.000000
# 9         2    21.718558    21.718558  3.900918    0.000000  0.000000
# 14        3    96.416626    85.735830  1.298726    0.000000  0.000000
# 24        5    83.668353    81.273653  1.899498  373.786832  1.062102
# 29        6  4452.508624  3041.876078  1.398558  178.323198  0.835525
# ...     ...          ...          ...       ...         ...       ...
# 1604    321    46.127035    24.632234  1.697523    3.465836  0.816870
# 1609    322  2179.242094  2029.697013  1.381756  200.694626  1.168521
# 1614    323     0.000000     0.000000  2.660207    0.000000  0.000000
# 1619    324   147.947620    26.546638  1.707757    5.098240  0.780065
# 1624    325     0.000000     0.000000  0.000000    1.338178  0.000000
#
# Series    TOT_ASSETS
# 4           0.000000
# 9          38.178685
# 14       1754.979053
# 24        235.481902
# 29      64743.030244
# ...              ...
# 1604     6850.295493
# 1609     5885.118080
# 1614       13.195865
# 1619      299.339725
# 1624        0.000000
#
# [306 rows x 7 columns]
